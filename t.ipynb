# %%
import os
from tqdm.auto import tqdm
from dotenv import load_dotenv
from pinecone import ServerlessSpec
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pinecone_text.sparse import BM25Encoder
from langchain_community.retrievers import PineconeHybridSearchRetriever
from langchain_cohere import CohereRerank
from langchain.chains import ConversationalRetrievalChain
from langchain_groq import ChatGroq
from pinecone import Pinecone
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
load_dotenv()
# Out:
# True

# %%
print("Loading and splitting documents...")
loader = PyPDFLoader("Carbon_adsorption.pdf")
documents = loader.load()
# Out:
# Loading and splitting documents...

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
docs = text_splitter.split_documents(documents)
print(f"Loaded and split {len(docs)} chunks.")
# Out:
# Loaded and split 41 chunks.

# %%
# --- 2. Initialize Pinecone and Create Index ---
print("Initializing Pinecone...")
pinecone_api_key = os.getenv("PINECONE_API_KEY")
if not pinecone_api_key:
    raise ValueError("PINECONE_API_KEY not found in environment variables.")

index_name = "langchain-test-index"  # change if desired
pc = Pinecone(api_key=pinecone_api_key)
if not pc.has_index(index_name):
    pc.create_index(
        name=index_name,
        dimension=1024,
        metric="dotproduct",
        spec=ServerlessSpec(cloud="aws", region="us-east-1"),
    )

index = pc.Index(index_name)
# Out:
# Initializing Pinecone...

# %%
gemini_api_key = os.getenv("GEMINI_API_KEY")

# embeddings = GoogleGenerativeAIEmbeddings(
#     model="models/embedding-001",
#     google_api_key=gemini_api_key,
#     max_retries=3,
#     timeout=60,
# )

from langchain_cohere import CohereEmbeddings

embeddings = CohereEmbeddings(model="embed-english-v3.0")
# embeddings = HuggingFaceEmbeddings(model_name="/home/rohan/models")
bm25_encoder = BM25Encoder().default()
print("Embeddings and sparse encoder initialized.")
# Out:
# [nltk_data] Downloading package punkt_tab to /home/pk/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /home/pk/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Embeddings and sparse encoder initialized.

# %%
# how many chunks produced locally
print("Num doc chunks:", len(docs))

# pinecone index stats (replace `index` with your Pinecone index object if different)
print("Index stats:", index.describe_index_stats())
# Out:
# Num doc chunks: 41
# Index stats: {'dimension': 1024,
#  'index_fullness': 0.0,
#  'metric': 'dotproduct',
#  'namespaces': {'': {'vector_count': 41}},
#  'total_vector_count': 41,
#  'vector_type': 'dense'}

# %%
# --- 4. Upsert Documents to Pinecone (Hybrid Search) ---
print("Upserting documents to Pinecone with hybrid search...")
batch_size = 100
for i in tqdm(range(0, len(docs), batch_size)):
    i_end = min(i + batch_size, len(docs))
    docs_batch = docs[i:i_end]
    
    # Get page content
    docs_content = [doc.page_content for doc in docs_batch]

    # Create sparse vectors
    sparse_embeds = bm25_encoder.encode_documents(docs_content)

    # Create dense vectors
    dense_embeds = embeddings.embed_documents(docs_content)

    # Create metadata
    metadata = [
        {
            "text": doc.page_content,
            "source": doc.metadata.get("source", "Unknown"),
            "page": doc.metadata.get("page", 0),
        }
        for doc in docs_batch
    ]

    # Create IDs
    ids = [f"doc_{i+j}" for j in range(len(docs_batch))]
    
    # Create vectors for upsert
    vectors_to_upsert = []
    for doc_id, sparse, dense, meta in zip(ids, sparse_embeds, dense_embeds, metadata):
        vectors_to_upsert.append({
            "id": doc_id,
            "sparse_values": sparse,
            "values": dense,
            "metadata": meta,
        })

    # Upsert to Pinecone
    index.upsert(vectors=vectors_to_upsert)

print("Documents upserted to Pinecone.")
# Out:
# Upserting documents to Pinecone with hybrid search...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Documents upserted to Pinecone.

# %%
# --- 5. Initialize Retriever with Hybrid Search ---
print("Initializing retriever with hybrid search...")
retriever = PineconeHybridSearchRetriever(
    embeddings=embeddings, sparse_encoder=bm25_encoder, index=index, text_key = "text", top_k=20
)
print("Retriever initialized.")
# Out:
# Initializing retriever with hybrid search...
# Retriever initialized.

# %%
groq_api_key = os.getenv("GROQ_API_KEY")

llm = ChatGroq(
    model = "llama-3.3-70b-versatile",
    temperature = 0.2,
    max_tokens = 32000
)

# %%
# --- 6. Initialize Reranker ---
print("Initializing Cohere reranker...")
cohere_api_key = os.getenv("COHERE_API_KEY")
if not cohere_api_key:
    raise ValueError("COHERE_API_KEY not found in environment variables.")
reranker = CohereRerank(model="rerank-english-v3.0")
print("Reranker initialized.")
# Out:
# Initializing Cohere reranker...
# Reranker initialized.

# %%
# --- 7. Create Conversational RAG Chain ---
print("Creating Conversational RAG Chain...")

# Use the default chain without custom prompt to avoid validation errors
qa_chain = ConversationalRetrievalChain.from_llm(
    llm=llm,
    retriever=retriever,
    condense_question_llm=llm,
    return_source_documents=True
)
print("Conversational RAG Chain created successfully.")
# Out:
# Creating Conversational RAG Chain...
# Conversational RAG Chain created successfully.

# %%
# --- 8. Run the RAG Agent ---
print("\n--- RAG Agent is Ready ---")
chat_history = []
while True:
    query = input("You: ")
    if query.lower() in ["exit", "quit"]:
        break
    
    result = qa_chain({"question": query, "chat_history": chat_history})
    
    # Rerank the retrieved documents
    reranked_docs = reranker.compress_documents(
        documents=result['source_documents'],
        query=query
    )
    
    print("\n--- Answer ---")
    print(result['answer'])
    print("\n--- Reranked Sources ---")
    for doc in reranked_docs:
        print(f"Source: {doc.metadata['source']}, Page: {doc.metadata['page']}")
        print(f"Content: {doc.page_content[:200]}...")
        print("-" * 20)
        
    chat_history.append((query, result["answer"]))
# Out:
# --- RAG Agent is Ready ---
#
# --- Answer ---
# Here are the abstracts:
#
# 1. Abstract: Carbon dioxide (CO2) capture technology is a prominent way to mitigate global climate change originating from the excessive emission of greenhouse gas CO2. The structural modification of adsorbents with amine is a new attractive strategy to enhance their CO2 adsorption efficiency under low pressure. The current work is looking to boost the CO2 uptake performance of Zeolitic imidazolate framework -8 (ZIF -8) impregnated with aminoethylethanolamine (AEEA) inside the porous network of crystalline ZIF-8 nanoparticles via the wet functionalization process due to the enormous surface area and remarkable thermally and chemical stability of ZIF -8.
#
# 2. Abstract: The rapid increase in atmospheric CO2 concentrations, driven by human activities, has become a critical factor in global climate change, posing severe risks to sustainable development. Addressing this challenge necessitates substantial CO2 removal, which demands innovative and efficient technologies. Carbon dioxide adsorption on porous materials is a promising strategy to mitigate this issue. This study investigates the synthesis of ordered mesoporous silica MCM-41 (Mobil Composition of Matter-41) by microwave irradiation, a technique that offers significant advantages over conventional hydrothermal methods.
#
# 3. Abstract: The utilization of eutectic molten salt technology has emerged as a prominent area of investigation aimed at fabricating a novel carbon material sorbent based on biomass wastes. The adsorption mechanism on CO2 adsorption remains inadequately elucidated as well. Herein, the biochar fabrication process involving eutectic molten salt method at intermediate-low temperature of 550 °C was successfully achieved and investigated in detail.
#
# 4. Abstract: Adsorption is fundamental to many industrial processes, including separation of carbon dioxide from other gases in pre- or post-combustion gas mixtures. Adsorbents should have high capacity and selectivity, which are both intimately linked with surface area, pore size distribution, and surface energy. Porous carbons are cheap and scalable adsorbents, but greater understanding of how their textural properties and surface chemistry affects their performance is needed.
#
# 5. Abstract: The utilization of in-situ heteroatom doping and carbonization techniques to produce porous biochar from waste biomass sources has the potential to significantly enhance electrochemical and CO2 adsorption performance of supercapacitors. In this work, an initiative N, S-codoped biochar was prepared through carbonation and KOH-activated pyrolysis of bagasse-based polycondensate precursors, which were synthesized using sugarcane bagasse as a carbon source, 3-amino-5-methio-1,2,4-triazole as a nitrogen and sulfur source and triglycidyl isocyanurate (TGIC) as a cross-linker, for efficient CO2 capture and energy storage.
#
# 6. Abstract: Cyanophyta blooms can lead to eutrophication and generate algal toxins. To reduce their environmental risks, hydrothermal carbonization was innovatively applied to simultaneously produce activated carbon (AC) and carbon dots (CDs). AC was further used for CO2 adsorption while CDs were for preparing fluorescent materials.
#
# 7. Abstract: To enhance CO2 sorption efficiency under low-pressure conditions and effectively compete with N2 sorption in flue gas, modifications are implemented aimed at improving the adsorption capacity and selectivity of ZIF-8, renowned for their robust stability. Deep eutectic solvent (DES) comprising tetraethylammonium chloride (TEAC), tetrapropylammonium chloride (TPAC), and tetrabutylammonium bromide (TBAB) as hydrogen-bond acceptors, along with ethanolamine (MEA) as the hydrogen-bond donor, were meticulously prepared for this purpose.
#
# 8. Abstract: The preparation of hierarchical porous silica aerogels from coal gasification fine slag (CGFS) offers an effective approach to achieving high-value utilization of solid waste and reducing the production cost of solid adsorbent matrix materials. However, the main challenges involve overcoming technical barriers to efficiently and value-added conversion of CGFS into silica aerogels with CO₂ adsorption properties, as well as elucidating the phase transformation mechanisms during the synthesis process.
#
# 9. Abstract: Activated carbon from agro-industrial waste, namely tea twigs derived from the processing of Camellia Sinensis branches, using a potassium hydroxide activator for CO2 adsorption has been conducted in this study. Various carbonization temperatures (4000C and 5000C) and heating times of 1 h and 3 h were used in this study.
#
# 10. Abstract: Resin-based porous carbon materials are considered to be an important direction for CO2 adsorption and supercapacitors due to their controllable chemical structure, large specific surface area, and stable physicochemical properties. But at present, the main source of resin-based porous carbon materials is petroleum-based polymer materials, which is incongruous with the tenets of green chemistry.
#
# 11. Abstract: A series of porous hypercrosslinked polymers (HCP-x) were synthesized from waste polystyrene foam via Fridel-Crafts alkylation reaction, aiming to optimize the utilization of waste plastics. The impact of various crosslinkers on the structural characteristics and CO2 adsorption properties of HCP-x was investigated.
#
# 12. Abstract: The utilization of ambient low-pressure CO2 adsorption for carbon neutrality initiatives holds great potential. However, conventional liquid amine absorption methods for CO2 capture are plagued by high energy consumption and equipment corrosion issues. In this study, we present a novel approach using industrial waste silica fume (SF) as a precursor and tetraethylenepentamine (TEPA) as a chemical modifying agent to efficiently synthesize low-cost mesoporous solid amine adsorbents within the waste-derived mesoporous powder sorbents (MPS) series.
#
# --- Reranked Sources ---
# Source: Carbon_adsorption.pdf, Page: 2.0
# Content: mmol/g at 100 kPa and 8.19 mmol/g at 2 MPa. At 323 K, the uptake further decreased to
# 0.99 ± 0.02 mmol/g at 100 kPa and 6.40 mmol/g at 2 MPa.
#
#
# https://doi.org/10.1016/j.seppur.2024.129054
#
# 5. A...
# --------------------
# Source: Carbon_adsorption.pdf, Page: 7.0
# Content: 11. Abstract:
#
# A series of porous hypercrosslinked polymers (HCP-x) were synthesized from waste
# polystyrene foam via Fridel-Crafts alkylation reaction, aiming to optimize the utilization of
# waste ...
# --------------------
# Source: Carbon_adsorption.pdf, Page: 0.0
# Content: Sno.  Text data
# 1. Abstract: Carbon dioxide (CO2) capture technology is a prominent way to mitigate global
# climate change originating from the excessive emission of greenhouse gas CO2. The
# structur...
# --------------------
# ---------------------------------------------------------------------------
# UnauthorizedException                     Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[17], line 9
#       7     break
# ----> 9 result = qa_chain({"question": query, "chat_history": chat_history})
#      11 # Rerank the retrieved documents
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:189, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     188     emit_warning()
# --> 189 return wrapped(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain/chains/base.py:410, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     403 config = {
#     404     "callbacks": callbacks,
#     405     "tags": tags,
#     406     "metadata": metadata,
#     407     "run_name": run_name,
#     408 }
# --> 410 return self.invoke(
#     411     inputs,
#     412     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     413     return_only_outputs=return_only_outputs,
#     414     include_run_info=include_run_info,
#     415 )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain/chains/base.py:165, in Chain.invoke(self, input, config, **kwargs)
#     163 self._validate_inputs(inputs)
#     164 outputs = (
# --> 165     self._call(inputs, run_manager=run_manager)
#     166     if new_arg_supported
#     167     else self._call(inputs)
#     168 )
#     170 final_outputs: dict[str, Any] = self.prep_outputs(
#     171     inputs,
#     172     outputs,
#     173     return_only_outputs,
#     174 )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain/chains/conversational_retrieval/base.py:164, in BaseConversationalRetrievalChain._call(self, inputs, run_manager)
#     163 if accepts_run_manager:
# --> 164     docs = self._get_docs(new_question, inputs, run_manager=_run_manager)
#     165 else:
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain/chains/conversational_retrieval/base.py:409, in ConversationalRetrievalChain._get_docs(self, question, inputs, run_manager)
#     408 """Get docs."""
# --> 409 docs = self.retriever.invoke(
#     410     question,
#     411     config={"callbacks": run_manager.get_child()},
#     412 )
#     413 return self._reduce_tokens_below_limit(docs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain_core/retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **kwargs_
#     261     )
#     262 else:
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain_community/retrievers/pinecone_hybrid_search.py:169, in PineconeHybridSearchRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#     168 # query pinecone with the query parameters
# --> 169 result = self.index.query(
#     170     vector=dense_vec,
#     171     sparse_vector=sparse_vec,
#     172     top_k=self.top_k,
#     173     include_metadata=True,
#     174     namespace=self.namespace,
#     175     **kwargs,
#     176 )
#     177 final_result = []
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/utils/error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/utils/error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/db_data/index.py:345, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     331 @validate_and_convert_errors
#     332 def query(
#     333     self,
#    (...)    343     **kwargs,
#     344 ) -> Union[QueryResponse, ApplyResult]:
# --> 345     response = self._query(
#     346         *args,
#     347         top_k=top_k,
#     348         vector=vector,
#     349         id=id,
#     350         namespace=namespace,
#     351         filter=filter,
#     352         include_values=include_values,
#     353         include_metadata=include_metadata,
#     354         sparse_vector=sparse_vector,
#     355         **kwargs,
#     356     )
#     358     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/db_data/index.py:395, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     384 request = IndexRequestFactory.query_request(
#     385     top_k=top_k,
#     386     vector=vector,
#    (...)    393     **kwargs,
#     394 )
# --> 395 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/core/openapi/db_data/api/vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/rest_utils.py:38, in raise_exceptions_or_return(r)
#      37 if r.status == 401:
# ---> 38     raise UnauthorizedException(http_resp=r)
#      40 if r.status == 403:
#
# UnauthorizedException: (401)
# Reason: Unauthorized
# HTTP response headers: HTTPHeaderDict({'Date': 'Sat, 23 Aug 2025 04:32:29 GMT', 'Content-Type': 'text/plain', 'Content-Length': '12', 'Connection': 'keep-alive', 'x-pinecone-auth-rejected-reason': 'Malformed domain', 'www-authenticate': 'Malformed domain', 'server': 'envoy'})
# HTTP response body: Unauthorized
#
#
# The above exception was the direct cause of the following exception:
#
# UnauthorizedException                     Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[17], line 9
#       7     break
# ----> 9 result = qa_chain({"question": query, "chat_history": chat_history})
#      11 # Rerank the retrieved documents
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:189, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     188     emit_warning()
# --> 189 return wrapped(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain/chains/base.py:410, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     403 config = {
#     404     "callbacks": callbacks,
#     405     "tags": tags,
#     406     "metadata": metadata,
#     407     "run_name": run_name,
#     408 }
# --> 410 return self.invoke(
#     411     inputs,
#     412     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     413     return_only_outputs=return_only_outputs,
#     414     include_run_info=include_run_info,
#     415 )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain/chains/base.py:165, in Chain.invoke(self, input, config, **kwargs)
#     163 self._validate_inputs(inputs)
#     164 outputs = (
# --> 165     self._call(inputs, run_manager=run_manager)
#     166     if new_arg_supported
#     167     else self._call(inputs)
#     168 )
#     170 final_outputs: dict[str, Any] = self.prep_outputs(
#     171     inputs,
#     172     outputs,
#     173     return_only_outputs,
#     174 )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain/chains/conversational_retrieval/base.py:164, in BaseConversationalRetrievalChain._call(self, inputs, run_manager)
#     163 if accepts_run_manager:
# --> 164     docs = self._get_docs(new_question, inputs, run_manager=_run_manager)
#     165 else:
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain/chains/conversational_retrieval/base.py:409, in ConversationalRetrievalChain._get_docs(self, question, inputs, run_manager)
#     408 """Get docs."""
# --> 409 docs = self.retriever.invoke(
#     410     question,
#     411     config={"callbacks": run_manager.get_child()},
#     412 )
#     413 return self._reduce_tokens_below_limit(docs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain_core/retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **kwargs_
#     261     )
#     262 else:
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain_community/retrievers/pinecone_hybrid_search.py:169, in PineconeHybridSearchRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#     168 # query pinecone with the query parameters
# --> 169 result = self.index.query(
#     170     vector=dense_vec,
#     171     sparse_vector=sparse_vec,
#     172     top_k=self.top_k,
#     173     include_metadata=True,
#     174     namespace=self.namespace,
#     175     **kwargs,
#     176 )
#     177 final_result = []
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/utils/error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/utils/error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/db_data/index.py:345, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     331 @validate_and_convert_errors
#     332 def query(
#     333     self,
#    (...)    343     **kwargs,
#     344 ) -> Union[QueryResponse, ApplyResult]:
# --> 345     response = self._query(
#     346         *args,
#     347         top_k=top_k,
#     348         vector=vector,
#     349         id=id,
#     350         namespace=namespace,
#     351         filter=filter,
#     352         include_values=include_values,
#     353         include_metadata=include_metadata,
#     354         sparse_vector=sparse_vector,
#     355         **kwargs,
#     356     )
#     358     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/db_data/index.py:395, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     384 request = IndexRequestFactory.query_request(
#     385     top_k=top_k,
#     386     vector=vector,
#    (...)    393     **kwargs,
#     394 )
# --> 395 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/core/openapi/db_data/api/vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/rest_utils.py:38, in raise_exceptions_or_return(r)
#      37 if r.status == 401:
# ---> 38     raise UnauthorizedException(http_resp=r)
#      40 if r.status == 403:
#
# UnauthorizedException: (401)
# Reason: Unauthorized
# HTTP response headers: HTTPHeaderDict({'Date': 'Sat, 23 Aug 2025 04:32:29 GMT', 'Content-Type': 'text/plain', 'Content-Length': '12', 'Connection': 'keep-alive', 'x-pinecone-auth-rejected-reason': 'Malformed domain', 'www-authenticate': 'Malformed domain', 'server': 'envoy'})
# HTTP response body: Unauthorized
#
#
# The above exception was the direct cause of the following exception:
#
# UnauthorizedException                     Traceback (most recent call last)
# Cell In[17], line 9
#       6 if query.lower() in ["exit", "quit"]:
#       7     break
# ----> 9 result = qa_chain({"question": query, "chat_history": chat_history})
#      11 # Rerank the retrieved documents
#      12 reranked_docs = reranker.compress_documents(
#      13     documents=result['source_documents'],
#      14     query=query
#      15 )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:189, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     187     warned = True
#     188     emit_warning()
# --> 189 return wrapped(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain/chains/base.py:410, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     378 """Execute the chain.
#     379
#     380 Args:
#    (...)    401         `Chain.output_keys`.
#     402 """
#     403 config = {
#     404     "callbacks": callbacks,
#     405     "tags": tags,
#     406     "metadata": metadata,
#     407     "run_name": run_name,
#     408 }
# --> 410 return self.invoke(
#     411     inputs,
#     412     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     413     return_only_outputs=return_only_outputs,
#     414     include_run_info=include_run_info,
#     415 )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain/chains/base.py:165, in Chain.invoke(self, input, config, **kwargs)
#     162 try:
#     163     self._validate_inputs(inputs)
#     164     outputs = (
# --> 165         self._call(inputs, run_manager=run_manager)
#     166         if new_arg_supported
#     167         else self._call(inputs)
#     168     )
#     170     final_outputs: dict[str, Any] = self.prep_outputs(
#     171         inputs,
#     172         outputs,
#     173         return_only_outputs,
#     174     )
#     175 except BaseException as e:
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain/chains/conversational_retrieval/base.py:164, in BaseConversationalRetrievalChain._call(self, inputs, run_manager)
#     160 accepts_run_manager = (
#     161     "run_manager" in inspect.signature(self._get_docs).parameters
#     162 )
#     163 if accepts_run_manager:
# --> 164     docs = self._get_docs(new_question, inputs, run_manager=_run_manager)
#     165 else:
#     166     docs = self._get_docs(new_question, inputs)  # type: ignore[call-arg]
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain/chains/conversational_retrieval/base.py:409, in ConversationalRetrievalChain._get_docs(self, question, inputs, run_manager)
#     401 def _get_docs(
#     402     self,
#     403     question: str,
#    (...)    406     run_manager: CallbackManagerForChainRun,
#     407 ) -> list[Document]:
#     408     """Get docs."""
# --> 409     docs = self.retriever.invoke(
#     410         question,
#     411         config={"callbacks": run_manager.get_child()},
#     412     )
#     413     return self._reduce_tokens_below_limit(docs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain_core/retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     257 kwargs_ = kwargs if self._expects_other_args else {}
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **kwargs_
#     261     )
#     262 else:
#     263     result = self._get_relevant_documents(input, **kwargs_)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/langchain_community/retrievers/pinecone_hybrid_search.py:169, in PineconeHybridSearchRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#     167 sparse_vec["values"] = [float(s1) for s1 in sparse_vec["values"]]
#     168 # query pinecone with the query parameters
# --> 169 result = self.index.query(
#     170     vector=dense_vec,
#     171     sparse_vector=sparse_vec,
#     172     top_k=self.top_k,
#     173     include_metadata=True,
#     174     namespace=self.namespace,
#     175     **kwargs,
#     176 )
#     177 final_result = []
#     178 for res in result["matches"]:
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/utils/error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      26     raise ProtocolError(
#      27         "Connection failed. Please verify that the index host is correct and accessible."
#      28     ) from e
#      29 else:
# ---> 30     raise e from e
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/utils/error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      12 @wraps(func)
#      13 def inner_func(*args, **kwargs):
#      14     try:
# ---> 15         return func(*args, **kwargs)
#      16     except Exception as e:
#      17         # Lazy import of urllib3 exceptions
#      18         from urllib3.exceptions import MaxRetryError, ProtocolError as Urllib3ProtocolError
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/db_data/index.py:345, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     331 @validate_and_convert_errors
#     332 def query(
#     333     self,
#    (...)    343     **kwargs,
#     344 ) -> Union[QueryResponse, ApplyResult]:
# --> 345     response = self._query(
#     346         *args,
#     347         top_k=top_k,
#     348         vector=vector,
#     349         id=id,
#     350         namespace=namespace,
#     351         filter=filter,
#     352         include_values=include_values,
#     353         include_metadata=include_metadata,
#     354         sparse_vector=sparse_vector,
#     355         **kwargs,
#     356     )
#     358     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#     359         return response
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/db_data/index.py:395, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     382     raise ValueError("top_k must be a positive integer")
#     384 request = IndexRequestFactory.query_request(
#     385     top_k=top_k,
#     386     vector=vector,
#    (...)    393     **kwargs,
#     394 )
# --> 395 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/core/openapi/db_data/api/vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     386 kwargs = self._process_openapi_kwargs(kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)    302         _check_type,
#     303     )
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#     186 return_data = response_data
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     376     return self.rest_client.OPTIONS(
#     377         url,
#     378         query_params=query_params,
#    (...)    383         body=body,
#     384     )
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#     396     return self.rest_client.PUT(
#     397         url,
#     398         query_params=query_params,
#    (...)    403         body=body,
#     404     )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     264     # log response body
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pinecone/openapi_support/rest_utils.py:38, in raise_exceptions_or_return(r)
#      36 if not 200 <= r.status <= 299:
#      37     if r.status == 401:
# ---> 38         raise UnauthorizedException(http_resp=r)
#      40     if r.status == 403:
#      41         raise ForbiddenException(http_resp=r)
#
# UnauthorizedException: (401)
# Reason: Unauthorized
# HTTP response headers: HTTPHeaderDict({'Date': 'Sat, 23 Aug 2025 04:32:29 GMT', 'Content-Type': 'text/plain', 'Content-Length': '12', 'Connection': 'keep-alive', 'x-pinecone-auth-rejected-reason': 'Malformed domain', 'www-authenticate': 'Malformed domain', 'server': 'envoy'})
# HTTP response body: Unauthorized

# %%
if pc.has_index(index_name):
    pc.delete_index(index_name)
